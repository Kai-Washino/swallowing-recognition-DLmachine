# %%
import sys
import os

# カレントディレクトリのパスを取得
current_dir = os.getcwd()

# 親ディレクトリへのパスを取得
parent_dir = os.path.dirname(current_dir)

# sys.pathに親ディレクトリのパスを追加
sys.path.append(parent_dir)
print(parent_dir)
# Out:
# /home/s2/Desktop/washino/swallowing-recognize

# %%
import swallowing_recognition

# %%
from swallowing_recognition import audio

# %%
wav1 = audio.Audio(parent_dir + '/dataset/washino/swallowing/swallowing150.wav')
wav1.original_plot()
wav1.trimmed_plot()
