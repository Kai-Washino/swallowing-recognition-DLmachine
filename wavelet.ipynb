# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav

# %%
import sys
import os
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
import swallowing_recognition

# %%
from swallowing_recognition import wavelet

# %%
sample_rate, data = wav.read(parent_dir + '/dataset/washino/swallowing/swallowing1.wav')
swallowing1 = wavelet.Wavelet(sample_rate, data)
swallowing1.generate_coefficients()
swallowing1.plot_spectrogram()
